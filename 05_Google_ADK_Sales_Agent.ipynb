# %% [markdown]
# # Multi-Agent Automated Sales Email System
# ### Using Google Agent Development Kit (ADK)
#
# This notebook demonstrates a multi-agent workflow using Google's ADK.
#
# Architecture:
#
# Sales Agents → Sales Manager → Email Manager → Tools (Subject + HTML + Send Email)

# %%
import os
import asyncio
from typing import Dict, List

# Gemini’s Agent Development Kit
from google import genai
# types is a module containing structured data classes used by the Gemini SDK
from google.genai import types

from dotenv import load_dotenv
import brevo_python
from brevo_python.api.transactional_emails_api import TransactionalEmailsApi
from brevo_python.models.send_smtp_email import SendSmtpEmail

# %% [markdown]
# ### Setup the API client to Gemini

# %%
load_dotenv(override=True)
# Initialize the new Client
client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))

# Client(
#     api_key="your_key",
#     http_options=...,   # optional networking config
# )

# returns:-
# client.models.generate_content()     # synchronous
# client.aio.models.generate_content()    #async calls

# %%
# Make a simple test request
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Tell a joke in one sentence."
)

# generate_content sends a request to Gemini model
# takes in the model, contents (system instructions) and config (tools, temperature etc.)

# Print the response
print(response.text)
# Out:
# What do you call a fake noodle? An impasta!

# %% [markdown]
# ### Setup the email sender

# %%
# --- Tool Definition ---
def send_email(subject: str, html_body: str) -> Dict[str, str]:
    """Sends a transactional email via Brevo.
    
    Args:
        subject: The subject line of the email.
        html_body: The HTML content of the email.
    """
    configuration = brevo_python.Configuration()
    configuration.api_key["api-key"] = os.getenv("BREVO_API_KEY")
    api_client = brevo_python.ApiClient(configuration)
    email_api = TransactionalEmailsApi(api_client)
    
    email = SendSmtpEmail(
        sender={"name": "Ayushi Saxena", "email": "khonthedark@gmail.com"},
        to=[{"email": "windwatcher17@gmail.com", "name": "Receiver"}],
        subject=subject,
        html_content=html_body
    )
    try:
        email_api.send_transac_email(email)
        return {"status": "success"}
    except Exception as e:
        return {"status": "error", "message": str(e)}

# List of available functional tools
tools_list = [send_email]

# %% [markdown]
# ### Agent Workflow

# %%
# System Instructions
instructions = {
    "professional": "You are a sales agent working for ComplAI, a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. You write professional, serious cold emails.",
    "engaging": "You are a humorous, engaging sales agent working for ComplAI, a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. You write witty, engaging cold emails that are likely to get a response.",
    "busy": "You are a busy sales agent working for ComplAI, a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. You write concise, to the point cold emails.",
    "sales_picker": "You pick the best cold sales email from the given options. Imagine you are a customer and pick the one you are most likely to respond to. Do not give an explanation; reply with the selected email only.",
    "manager": """You are a Sales Manager at ComplAI. Your goal is to find the single best cold sales email using the email_manager_handoff tools.
        Follow these steps carefully:
        1. Generate Drafts: Use all three email draft tools (get_professional_draft, get_engaging_draft, get_busy_draft) to generate three different email drafts. Do not proceed until all three drafts are ready.
        2. Evaluate and Select: Review the drafts and choose the single best email using your judgment of which one is most effective.
        3. Use the email_manager_handoff tool to send the best email (and only the best email) to the user.
        Crucial Rules:
        - You must use the get draft tools to generate the drafts — do not write them yourself.
        - You must send ONE email using the email_manager_handoff tool — never more than one.""",
    "subject": "You write email subjects likely to get a response based on the message provided.",
    "html": "You convert text email bodies to clear, compelling HTML layouts.",
}

# %% [markdown]
# ### Agent Wrappers (Tools)

# %% [markdown]
# Gemini uses function calling to simulate "agents calling agents"

# %%
async def get_professional_draft(request: str) -> str:
    """Generate a professional cold sales email draft."""
    # Await an asynchronous API call to Gemini
    # `client.aio` is the async version of the SDK client
    res = await client.aio.models.generate_content(
        model="gemini-2.5-flash",
        config=types.GenerateContentConfig(system_instruction=instructions["professional"]),
        contents=request
    )
    return res.text

# %%
async def get_engaging_draft(request: str) -> str:
    """Generate a witty and engaging cold sales email draft."""
    res = await client.aio.models.generate_content(
        model="gemini-2.5-flash",
        config=types.GenerateContentConfig(system_instruction=instructions["engaging"]),
        contents=request
    )
    return res.text

# %%
async def get_busy_draft(request: str) -> str:
    """Generate a concise and busy cold sales email draft."""
    res = await client.aio.models.generate_content(
        model="gemini-2.5-flash",
        config=types.GenerateContentConfig(system_instruction=instructions["busy"]),
        contents=request
    )
    return res.text

# %%
async def email_manager_handoff(email_body: str) -> str:
    """
    Handoff the winning email draft to the Email Manager for formatting and sending.
    Args:
        email_body: The text of the winning email.
    """
    print(f"\n--- Handoff to Email Manager ---\n")
    
    # 1. Get Subject
    subj_res = await client.aio.models.generate_content(
        model="gemini-2.5-flash",
        config=types.GenerateContentConfig(system_instruction=instructions["subject"]),
        contents=f"Write a subject for: {email_body}"
    )
    subject = subj_res.text

    # 2. Convert to HTML
    html_res = await client.aio.models.generate_content(
        model="gemini-2.5-flash",
        config=types.GenerateContentConfig(system_instruction=instructions["html"]),
        contents=email_body
    )
    html_content = html_res.text

    # 3. Send via Brevo
    send_email(subject=subject, html_body=html_content)
    return "Email formatted and sent successfully."

# %% [markdown]
# ### Simulate Running Agents Concurrently

# %%
message = "Write a cold sales email."

draft_tasks = [
    get_professional_draft(message),
    get_engaging_draft(message),
    get_busy_draft(message)
]

drafts = await asyncio.gather(*draft_tasks)

print(drafts)
# Out:
# ["Subject: Streamline Your SOC 2 Compliance & Audit Prep with AI | ComplAI\n\nDear [Prospect's Name],\n\nI'm reaching out from ComplAI because I understand that navigating the complexities of SOC 2 compliance and preparing for audits can be a significant challenge for growing organizations like [Prospect's Company Name]. The manual effort, potential for oversight, and the constant demand on internal resources often divert focus from core business objectives.\n\nThis is precisely where ComplAI offers a transformative solution. We provide an AI-powered SaaS platform specifically designed to simplify and accelerate your SOC 2 journey. Our tool automates critical compliance processes, proactively identifies gaps, streamlines evidence collection, and ensures you are continuously audit-ready – all with unparalleled efficiency and accuracy.\n\nImagine reducing the time, cost, and stress traditionally associated with SOC 2, while simultaneously enhancing your security posture and demonstrating robust compliance to auditors with confidence. ComplAI makes this a reality by acting as your intelligent co-pilot through every stage of compliance.\n\nWould you be open to a brief, 15-minute call next week to quickly demonstrate how ComplAI could specifically benefit [Prospect's Company Name] and address your current SOC 2 challenges?\n\nPlease let me know if there's a day or time that works best for you.\n\nThank you for your time and consideration.\n\nSincerely,\n\n[Your Name]\nSales Director\nComplAI\n[Your Phone Number]\n[Your Email]\n[ComplAI Website]", 'Subject: SOC2 Compliance: Less \'OMG\' More \'Oh, My AI!\'\n\nHi [Prospect\'s Name],\n\nI was doing a bit of digital sleuthing (don\'t worry, it\'s for good, not evil!) and noticed [Company Name] is doing some impressive things in [their industry/area of work].\n\nWhich got me thinking... how\'s your relationship with SOC2 compliance? Is it a beautiful, harmonious partnership, or more like that one relative who only calls when they need something (and usually it\'s *a lot* of something)?\n\nIf you\'ve ever stared at a spreadsheet filled with controls and felt like you were trying to herd digital cats while blindfolded, you\'re not alone. The manual grunt work, the endless document chasing, the existential dread before an audit – it\'s less "compliance" and more "a full-time job for a team of angels wearing tinfoil hats."\n\nThat\'s where ComplAI waltzes in, probably humming a jaunty tune.\n\nWe\'ve built an AI-powered SaaS tool that basically *is* that team of angels, but without the tinfoil hats (unless you want them, we don\'t judge). Our platform automates the mind-numbing data collection, identifies compliance gaps *before* your auditor does (saving you awkward conversations), and helps you prep for audits with the confidence of a rockstar playing their greatest hits.\n\nThink less manual headache, fewer panic-induced coffee binges, and more "Oh, *that\'s* how easy SOC2 can be?" moments. We turn compliance dread into... well, not *joy*, but definitely relief. And maybe a bit of smug satisfaction.\n\nHow about a quick 15-minute chat? No high-pressure sales tactics, just a friendly conversation where I can show you how ComplAI helps future-proof your compliance and lets your team focus on what they do best – building awesome things at [Company Name].\n\nYou can grab a slot directly on my calendar here: [Link to your scheduling tool]\n\nLooking forward to banishing those compliance monsters with you!\n\nBest,\n\n[Your Name]\nChief Anti-Dread Officer (aka Sales Agent)\nComplAI - Making Compliance Compl-Easy (You\'re welcome for that pun.)\n[Your Website] | [Your LinkedIn (Optional)]', 'Subject: Simplify SOC2 & Audit Prep with AI\n\nHi [Prospect Name],\n\nDealing with SOC2 compliance and upcoming audits can be a significant headache, consuming valuable time and resources.\n\nComplAI is an AI-powered SaaS tool that automates your entire SOC2 journey. We help you maintain continuous complian ...

# %%
async def run_manager_agent(message: str):

    manager_tools = [get_professional_draft, get_engaging_draft, get_busy_draft, email_manager_handoff]

    # Map tool name → function
    tool_map = {
        "get_professional_draft": get_professional_draft,
        "get_engaging_draft": get_engaging_draft,
        "get_busy_draft": get_busy_draft,
        "email_manager_handoff": email_manager_handoff
    }

    # contents = message
    conversation = [message]

    while True:

        response = await client.aio.models.generate_content(
            model="gemini-2.5-flash",
            config=types.GenerateContentConfig(
                system_instruction=instructions["manager"],
                tools=manager_tools,
                automatic_function_calling=types.AutomaticFunctionCallingConfig(disable=True) 
            ),
            contents=conversation
        )

        candidate = response.candidates[0]
        parts = candidate.content.parts
        conversation.append(candidate.content)

        tool_called = False

        for part in parts:
            # MODEL IS REQUESTING TOOL EXECUTION
            if hasattr(part, "function_call") and part.function_call:
                tool_called = True
                tool_name = part.function_call.name
                tool_args = dict(part.function_call.args)
                print(f"Tool requested: {tool_name}")
                print(f"Arguments: {tool_args}")
                # Execute tool
                tool_fn = tool_map[tool_name]
                result = await tool_fn(**tool_args)
                print(f"Tool result: {result}")
                # Append tool response
                conversation.append(
                    types.Content(
                        role="tool",
                        parts=[
                            types.Part.from_function_response(
                                name=tool_name,
                                response={"result": result}
                            )
                        ]
                    )
                )
                break

        # If no tool requested → final answer
        if not tool_called:
            print("\nFINAL MANAGER OUTPUT:\n")
            print(response.text)
            return response.text

# %%
async def main():
    message = "Send out a cold sales email addressed to Dear CEO from Ayushi Saxena"
    print("Sales Manager evaluating and handing off...")
    await run_manager_agent(message)

await main()
# Out:
# Sales Manager evaluating and handing off...
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[41], line 6
#       3     print("Sales Manager evaluating and handing off...")
#       4     await run_manager_agent(message)
# ----> 6 await main()
#
# Cell In[41], line 4, in main()
#       2 message = "Send out a cold sales email addressed to Dear CEO from Ayushi Saxena"
#       3 print("Sales Manager evaluating and handing off...")
# ----> 4 await run_manager_agent(message)
#
# Cell In[39], line 18, in run_manager_agent(message)
#      14 conversation = [message]
#      16 while True:
# ---> 18     response = await client.aio.models.generate_content(
#      19         model="gemini-2.5-flash",
#      20         config=types.GenerateContentConfig(
#      21             system_instruction=instructions["manager"],
#      22             tools=manager_tools,
#      23             automatic_function_calling=types.AutomaticFunctionCallingConfig(disable=True)
#      24         ),
#      25         contents=conversation
#      26     )
#      28     candidate = response.candidates[0]
#      29     parts = candidate.content.parts
#
# File d:\Agentic_AI\AI_Agents\AI-Agents\venv\Lib\site-packages\google\genai\models.py:7298, in AsyncModels.generate_content(self, model, contents, config)
#    7294 parsed_config, mcp_to_genai_tool_adapters = (
#    7295     await _extra_utils.parse_config_for_mcp_sessions(config)
#    7296 )
#    7297 if _extra_utils.should_disable_afc(parsed_config):
# -> 7298   return await self._generate_content(
#    7299       model=model, contents=contents, config=parsed_config
#    7300   )
#    7301 if incompatible_tools_indexes:
#    7302   original_tools_length = 0
#
# File d:\Agentic_AI\AI_Agents\AI-Agents\venv\Lib\site-packages\google\genai\models.py:6095, in AsyncModels._generate_content(self, model, contents, config)
#    6092 request_dict = _common.convert_to_dict(request_dict)
#    6093 request_dict = _common.encode_unserializable_types(request_dict)
# -> 6095 response = await self._api_client.async_request(
#    6096     'post', path, request_dict, http_options
#    6097 )
#    6099 if config is not None and getattr(
#    6100     config, 'should_return_http_response', None
#    6101 ):
#    6102   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File d:\Agentic_AI\AI_Agents\AI-Agents\venv\Lib\site-packages\google\genai\_api_client.py:1442, in BaseApiClient.async_request(self, http_method, path, request_dict, http_options)
#    1431 async def async_request(
#    1432     self,
#    1433     http_method: str,
#    (...)   1436     http_options: Optional[HttpOptionsOrDict] = None,
#    1437 ) -> SdkHttpResponse:
#    1438   http_request = self._build_request(
#    1439       http_method, path, request_dict, http_options
#    1440   )
# -> 1442   result = await self._async_request(
#    1443       http_request=http_request, http_options=http_options, stream=False
#    1444   )
#    1445   response_body = result.response_stream[0] if result.response_stream else ''
#    1446   return SdkHttpResponse(headers=result.headers, body=response_body)
#
# File d:\Agentic_AI\AI_Agents\AI-Agents\venv\Lib\site-packages\google\genai\_api_client.py:1375, in BaseApiClient._async_request(self, http_request, http_options, stream)
#    1373     retry = tenacity.AsyncRetrying(**retry_kwargs)
#    1374     return await retry(self._async_request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1375 return await self._async_retry(  # type: ignore[no-any-return]
#    1376     self._async_request_once, http_request, stream
#    1377 )
#
# File d:\Agentic_AI\AI_Agents\AI-Agents\venv\Lib\site-packages\tenacity\asyncio\__init__.py:111, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#     109 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     110 while True:
# --> 111     do = await self.iter(retry_state=retry_state)
#     112     if isinstance(do, DoAttempt):
#     113         try:
#
# File d:\Agentic_AI\AI_Agents\AI-Agents\venv\Lib\site-packages\tenacity\asyncio\__init__.py:153, in AsyncRetrying.iter(self, retry_state)
#     151 result = None
#     152 for action in self.iter_state.actions:
# --> 153     result = await action(retry_state)
#     154 return result
#
# File d:\Agentic_AI\AI_Agents\AI-Agents\venv\Lib\site-packages\tenacity\_utils.py:99, in wrap_to_async_func.<locals>.inner(*args, **kwargs)
#      98 async def inner(*args: typing.Any, **kwargs: typing.Any) -> typing.Any:
# ---> 99     return call(*args, **kwargs)
#
# File d:\Agentic_AI\AI_Agents\AI-Agents\venv\Lib\site-packages\tenacity\__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     418 retry_exc = self.retry_error_cls(fut)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File d:\Agentic_AI\AI_Agents\AI-Agents\venv\Lib\site-packages\tenacity\__init__.py:187, in RetryError.reraise(self)
#     185 def reraise(self) -> t.NoReturn:
#     186     if self.last_attempt.failed:
# --> 187         raise self.last_attempt.result()
#     188     raise self
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File d:\Agentic_AI\AI_Agents\AI-Agents\venv\Lib\site-packages\tenacity\asyncio\__init__.py:114, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#     112 if isinstance(do, DoAttempt):
#     113     try:
# --> 114         result = await fn(*args, **kwargs)
#     115     except BaseException:  # noqa: B902
#     116         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File d:\Agentic_AI\AI_Agents\AI-Agents\venv\Lib\site-packages\google\genai\_api_client.py:1355, in BaseApiClient._async_request_once(self, http_request, stream)
#    1346 else:
#    1347   # aiohttp is not available. Fall back to httpx.
#    1348   client_response = await self._async_httpx_client.request(
#    1349       method=http_request.method,
#    1350       url=http_request.url,
#    (...)   1353       timeout=http_request.timeout,
#    1354   )
# -> 1355   await errors.APIError.raise_for_async_response(client_response)
#    1356   return HttpResponse(client_response.headers, [client_response.text])
#
# File d:\Agentic_AI\AI_Agents\AI-Agents\venv\Lib\site-packages\google\genai\errors.py:216, in APIError.raise_for_async_response(cls, response)
#     213   except ImportError:
#     214     raise ValueError(f'Unsupported response type: {type(response)}')
# --> 216 await cls.raise_error_async(status_code, response_json, response)
#
# File d:\Agentic_AI\AI_Agents\AI-Agents\venv\Lib\site-packages\google\genai\errors.py:238, in APIError.raise_error_async(cls, status_code, response_json, response)
#     224 """Raises an appropriate APIError subclass based on the status code.
#     225
#     226 Args:
#    (...)    235   APIError: For other error status codes.
#     236 """
#     237 if 400 <= status_code < 500:
# --> 238   raise ClientError(status_code, response_json, response)
#     239 elif 500 <= status_code < 600:
#     240   raise ServerError(status_code, response_json, response)
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 9.942071372s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '9s'}]}}

# %% [markdown]
# <hr>
